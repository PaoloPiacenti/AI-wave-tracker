# %% [markdown]
# # Installing packages

# %%
# %pip install git+https://github.com/THU-MIG/yolov10.git
# Out:
# Collecting git+https://github.com/THU-MIG/yolov10.git
#   Cloning https://github.com/THU-MIG/yolov10.git to /private/var/folders/9j/h4l0p2dx7px95c35wm6htgr40000gn/T/pip-req-build-sznpronr
#   Running command git clone --filter=blob:none --quiet https://github.com/THU-MIG/yolov10.git /private/var/folders/9j/h4l0p2dx7px95c35wm6htgr40000gn/T/pip-req-build-sznpronr
#   Resolved https://github.com/THU-MIG/yolov10.git to commit cd2f79c70299c9041fb6d19617ef1296f47575b1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (1.14.1)
# Collecting torch>=1.8.0 (from ultralytics==8.1.34)
#   Downloading torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting torchvision>=0.9.0 (from ultralytics==8.1.34)
#   Downloading torchvision-0.17.2-cp310-cp310-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (4.66.5)
# Requirement already satisfied: psutil in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (6.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics==8.1.34)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ultralytics==8.1.34) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2024.7.4)
# Requirement already satisfied: filelock in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (4.12.2)
# Requirement already satisfied: sympy in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (1.13.2)
# Requirement already satisfied: networkx in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.3)
# Requirement already satisfied: jinja2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.1.4)
# Collecting fsspec (from torch>=1.8.0->ultralytics==8.1.34)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: six>=1.5 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.1.34) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.1.34) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics==8.1.34) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl (150.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 37.2 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.17.2-cp310-cp310-macosx_10_13_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.5 MB/s eta 0:00:00
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Building wheels for collected packages: ultralytics
#   Building wheel for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=731411 sha256=9d81ebbecfc8a6e52e0096d898b3e01e9d0e134ddcd9509c7666f85bfb34e766
#   Stored in directory: /private/var/folders/9j/h4l0p2dx7px95c35wm6htgr40000gn/T/pip-ephem-wheel-cache-qhmsgk5v/wheels/43/69/ce/a29f8e396d41edc5db9476051cc64b70a69ade35dc81efbec9
# Successfully built ultralytics
# Installing collected packages: fsspec, torch, torchvision, thop, ultralytics
# Successfully installed fsspec-2024.6.1 thop-0.1.1.post2209072238 torch-2.2.2 torchvision-0.17.2 ultralytics-8.1.34
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install huggingface_hub
# Out:
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests->huggingface_hub) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests->huggingface_hub) (2024.7.4)
# Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Installing collected packages: huggingface_hub
# Successfully installed huggingface_hub-0.24.6

# %%
# !pip install --upgrade jupyter
# Out:
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: notebook in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter) (7.2.1)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter) (6.29.5)
# Collecting ipywidgets (from jupyter)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jupyterlab in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter) (4.2.4)
# Requirement already satisfied: appnope in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipykernel->jupyter) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->jupyter)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->jupyter)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-console->jupyter) (3.0.47)
# Requirement already satisfied: pygments in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (72.1.0)
# Requirement already satisfied: tomli>=1.2.2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab->jupyter) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab->jupyter) (4.12.2)
# Requirement already satisfied: six>=1.9.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.4.0)
# Requirement already satisfied: certifi in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.5)
# Requirement already satisfied: idna in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: sniffio in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.31.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (1.26.19)
# Requirement already satisfied: executing>=1.2.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.0)
# Requirement already satisfied: pycparser in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20240821)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 18.9 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets, jupyter-console, jupyter
# Successfully installed ipywidgets-8.1.5 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
# !pip install --upgrade ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipywidgets) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /Users/Paolo/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %% [markdown]
# # Importing Yolo V10 Model Trained (Best)

# %%
from ultralytics import YOLOv10

# %%
model_path = '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/models/weights_of_train_39/weights_best_&_last_pt/best.pt'

# %%
model = YOLOv10(model_path)

# %% [markdown]
# # Test Best Model in some random images

# %%
import os
import random

def get_random_image_path(folder_path):
    """
    Selects a random image from the given folder and returns its absolute path.
    
    :param folder_path: Path to the folder containing images.
    :return: Absolute path of the selected random image.
    """
    # List all files in the directory
    all_files = os.listdir(folder_path)
    
    # Filter out image files based on common extensions
    image_extensions = ('.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff')
    image_files = [f for f in all_files if f.lower().endswith(image_extensions)]
    
    # Ensure there are images to select from
    if not image_files:
        raise ValueError("No images found in the folder.")
    
    # Randomly select one image
    selected_image = random.choice(image_files)
    
    # Construct the absolute path
    selected_image_path = os.path.abspath(os.path.join(folder_path, selected_image))
    
    return selected_image_path

# %%
folder_path = '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/data/images/test'

# %%
images = {}

try:
    for i in range(5):
        images[i] = get_random_image_path(folder_path)
except ValueError as e:
    print(e)

# %%
image = model(images[3])
image[0].boxes
image[0].show()
# Out:
# image 1/1 /Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/data/images/test/Surfing-Sunday-in-Caparica-28_03_2021-_frame_21_jpg.rf.0009eda0f23631e8c2d4d4db634b0f64.jpg: 640x640 1 pocket, 406.9ms
# Speed: 10.5ms preprocess, 406.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # Predict on straming

# %%
import cv2
import torch
from IPython.display import display, clear_output
from PIL import Image
import requests
from io import BytesIO

# Initialize the YOLOv8 model (replace with your trained model's path) # or 'path/to/your/custom/model.pt'

def stream_and_predict(beach):
    # Stream URL
    stream_url = f'https://video-auth1.iol.pt/beachcam/{beach}/playlist.m3u8'

    # Initialize video capture
    cap = cv2.VideoCapture(stream_url)

    # Check if the video capture has been initialized correctly
    if not cap.isOpened():
        print(f"Error: Could not open video stream for {beach}")
        return

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            print("Error: Couldn't read frame.")
            break

        # Apply YOLOv8 model to detect objects in the frame
        
        results = model(frame)

        # Draw bounding boxes on the frame
        for r in results:
            boxes = r.boxes.xyxy  # x1, y1, x2, y2
            confs = r.boxes.conf  # Confidence scores
            classes = r.boxes.cls  # Class IDs

            for box, conf, cls in zip(boxes, confs, classes):
                # Extract the coordinates
                x1, y1, x2, y2 = map(int, box)
                
                # Draw the rectangle
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                
                # Annotate with the class and confidence
                label = f'{model.names[int(cls)]}: {conf:.2f}'
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Convert frame to PIL image for display in Jupyter notebook
        img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        
        # Display the frame using IPython display
        clear_output(wait=True)
        display(img)

        # Break loop if you want to stop the execution
        # Here we don't wait for 'q' keypress, because it's impractical in a Jupyter notebook
        # You can insert a break condition based on a certain number of frames or an external trigger
        # For now, this will run indefinitely unless manually interrupted

    # Release the capture
    cap.release()

# %%
def _on_timeout(proc, status_dict):
    status_dict['timeout'] = True
    proc.kill()

# %%
stream_and_predict('praiagrande')
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 stream_and_predict('praiagrande')
#
# Cell In[41], line 30, in stream_and_predict(beach)
#      26     break
#      28 # Apply YOLOv8 model to detect objects in the frame
# ---> 30 results = model.track(frame)
#      32 # Draw bounding boxes on the frame
#      33 for r in results:
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/engine/model.py:481, in Model.track(self, source, stream, persist, **kwargs)
#     479 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     480 kwargs["mode"] = "track"
# --> 481 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/engine/model.py:441, in Model.predict(self, source, stream, predictor, **kwargs)
#     439 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     440     self.predictor.set_prompts(prompts)
# --> 441 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/engine/predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/nn/autobackend.py:422, in AutoBackend.forward(self, im, augment, visualize, embed)
#     420 # PyTorch
#     421 if self.pt or self.nn_module:
# --> 422     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     424 # TorchScript
#     425 elif self.jit:
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/nn/tasks.py:94, in BaseModel.forward(self, x, *args, **kwargs)
#      92 if isinstance(x, dict):  # for cases of training and validating while training.
#      93     return self.loss(x, *args, **kwargs)
# ---> 94 return self.predict(x, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/nn/tasks.py:112, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     110 if augment:
#     111     return self._predict_augment(x)
# --> 112 return self._predict_once(x, profile, visualize, embed)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/nn/tasks.py:133, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     131 if profile:
#     132     self._profile_one_layer(m, x, dt)
# --> 133 x = m(x)  # run
#     134 y.append(x if m.i in self.save else None)  # save output
#     135 if visualize:
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/nn/modules/block.py:231, in C2f.forward(self, x)
#     229 def forward(self, x):
#     230     """Forward pass through C2f layer."""
# --> 231     y = list(self.cv1(x).chunk(2, 1))
#     232     y.extend(m(y[-1]) for m in self.m)
#     233     return self.cv2(torch.cat(y, 1))
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/modules/activation.py:393, in SiLU.forward(self, input)
#     392 def forward(self, input: Tensor) -> Tensor:
# --> 393     return F.silu(input, inplace=self.inplace)
#
# File ~/.pyenv/versions/3.10.6/envs/wave_pocket_detection/lib/python3.10/site-packages/torch/nn/functional.py:2074, in silu(input, inplace)
#    2072     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2073 if inplace:
# -> 2074     return torch._C._nn.silu_(input)
#    2075 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:

# %% [markdown]
# # Object Tracking

# %%
video_path = "/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4"

# %%
results = model.track(video_path, show=False)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1873) /Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4: 384x640 1 pocket, 274.5ms
# video 1/1 (frame 2/1873) /Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4: 384x640 1 pocket,
3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.1ms
# video 1/1 (frame 786/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 37.3ms
# video 1/1 (frame 787/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 34.0ms
# video 1/1 (frame 788/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 33.5ms
# video 1/1 (frame 789/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 34.2ms
# video 1/1 (frame 790/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 37.2ms
# video 1/1 (frame 791/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.9ms
# video 1/1 (frame 792/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.7ms
# video 1/1 (frame 793/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 42.5ms
# video 1/1 (frame 794/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.9ms
# video 1/1 (frame 795/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 44.1ms
# video 1/1 (frame 796/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 57.6ms
# video 1/1 (frame 797/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 62.1ms
# video 1/1 (frame 798/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 39.5ms
# video 1/1 (frame 799/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 37.4ms
# video 1/1 (frame 800/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.6ms
# video 1/1 (frame 801/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 38.9ms
# video 1/1 (frame 802/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 38.0ms
# video 1/1 (frame 803/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 37.8ms
# video 1/1 (frame 804/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 38.9ms
# video 1/1 (frame 805/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.1ms
# video 1/1 (frame 806/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.2ms
# video 1/1 (frame 807/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.0ms
# video 1/1 (frame 808/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.3ms
# video 1/1 (frame 809/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.1ms
# video 1/1 (frame 810/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 52.9ms
# video 1/1 (frame 811/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 51.5ms
# video 1/1 (frame 812/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 49.0ms
# video 1/1 (frame 813/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.3ms
# video 1/1 (frame 814/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 39.5ms
# video 1/1 (frame 815/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 49.2ms
# video 1/1 (frame 816/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 45.4ms
# video 1/1 (frame 817/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 47.0ms
# video 1/1 (frame 818/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.6ms
# video 1/1 (frame 819/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.5ms
# video 1/1 (frame 820/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 37.7ms
# video 1/1 (frame 821/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 36.3ms
# video 1/1 (frame 822/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 34.7ms
# video 1/1 (frame 823/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 33.9ms
# video 1/1 (frame 824/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.5ms
# video 1/1 (frame 825/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 34.1ms
# video 1/1 (frame 826/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.2ms
# video 1/1 (frame 827/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 37.0ms
# video 1/1 (frame 828/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 34.6ms
# video 1/1 (frame 829/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 34.8ms
# video 1/1 (frame 830/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.7ms
# video 1/1 (frame 831/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.8ms
# video 1/1 (frame 832/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 34.3ms
# video 1/1 (frame 833/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.7ms
# video 1/1 (frame 834/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 37.6ms
# video 1/1 (frame 835/3115) /home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4: 416x640 (no detections), 35.9ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 results = model.track('/home/chicocheta/code/PaoloPiacenti/backup/Data/Live Surf Cam_ Uluwatu, Bali - YouTube — Mozilla Firefox 2024-08-29 17-59-26.mp4', show=True)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/ultralytics/engine/model.py:481, in Model.track(self, source, stream, persist, **kwargs)
#     479 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     480 kwargs["mode"] = "track"
# --> 481 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/ultralytics/engine/model.py:441, in Model.predict(self, source, stream, predictor, **kwargs)
#     439 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     440     self.predictor.set_prompts(prompts)
# --> 441 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/torch/utils/_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/ultralytics/engine/predictor.py:244, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     242 # Preprocess
#     243 with profilers[0]:
# --> 244     im = self.preprocess(im0s)
#     246 # Inference
#     247 with profilers[1]:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/ultralytics/engine/predictor.py:129, in BasePredictor.preprocess(self, im)
#     126     im = np.ascontiguousarray(im)  # contiguous
#     127     im = torch.from_numpy(im)
# --> 129 im = im.to(self.device)
#     130 im = im.half() if self.model.fp16 else im.float()  # uint8 to fp16/32
#     131 if not_tensor:
#
# KeyboardInterrupt:

# %%
type(results)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [124, 133, 148],
#          [124, 133, 148],
#          [124, 133, 148]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [102, 111, 126],
#          [102, 111, 126],
#          [102, 111, 126]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [112, 121, 136],
#          [112, 121, 136],
#          [112, 121, 136]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 10.442972183227539, 'inference': 485.4729175567627, 'postprocess': 15.192031860351562},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [157, 166, 181],
#          [157, 166, 181],
#          [157, 166, 181]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [159, 165, 181],
#          [159, 165, 181],
#          [159, 165, 181]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 5.006074905395508, 'inference': 223.36411476135254, 'postprocess': 0.5080699920654297},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [157, 166, 181],
#          [157, 166, 181],
#          [157, 166, 181]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [159, 165, 181],
#          [159, 165, 181],
#          [159, 165, 181]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.249095916748047, 'inference': 202.10003852844238, 'postprocess': 0.5328655242919922},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[127, 119, 114],
#          [127, 119, 114],
#          [127, 119, 114],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [167, 176, 191],
#          [167, 176, 191],
#          [167, 176, 191]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [170, 176, 192],
#          [170, 176, 192],
#          [170, 176, 192]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [171, 177, 193],
#          [171, 177, 193],
#          [171, 177, 193]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.4971237182617188, 'inference': 190.98186492919922, 'postprocess': 0.5359649658203125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [169, 175, 191],
#          [169, 175, 191],
#          [169, 175, 191]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [172, 176, 192],
#          [172, 176, 192],
#          [172, 176, 192]],
#
#         [[108, 108, 115],
#          [108, 108, 115],
#          [108, 108, 115],
#          ...,
#          [173, 177, 193],
#          [173, 177, 193],
#          [173, 177, 193]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.5169849395751953, 'inference': 191.7581558227539, 'postprocess': 0.49495697021484375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [169, 175, 191],
#          [169, 175, 191],
#          [169, 175, 191]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [172, 176, 192],
#          [172, 176, 192],
#          [172, 176, 192]],
#
#         [[ 58,  58,  65],
#          [ 58,  58,  65],
#          [ 58,  58,  65],
#          ...,
#          [173, 177, 193],
#          [173, 177, 193],
#          [173, 177, 193]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 5.724906921386719, 'inference': 184.22317504882812, 'postprocess': 0.5102157592773438},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [164, 170, 186],
#          [164, 170, 186],
#          [164, 170, 186]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [164, 170, 186],
#          [164, 170, 186],
#          [164, 170, 186]],
#
#         [[ 58,  58,  65],
#          [ 58,  58,  65],
#          [ 58,  58,  65],
#          ...,
#          [164, 170, 186],
#          [164, 170, 186],
#          [164, 170, 186]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.3946762084960938, 'inference': 203.0339241027832, 'postprocess': 0.6449222564697266},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 71,  71,  78],
#          [ 71,  71,  78],
#          [ 71,  71,  78],
#          ...,
#          [161, 170, 185],
#          [161, 170, 185],
#          [161, 170, 185]],
#
#         [[ 64,  64,  71],
#          [ 64,  64,  71],
#          [ 64,  64,  71],
#          ...,
#          [163, 169, 185],
#          [163, 169, 185],
#          [163, 169, 185]],
#
#         [[ 58,  58,  65],
#          [ 58,  58,  65],
#          [ 58,  58,  65],
#          ...,
#          [163, 169, 185],
#          [163, 169, 185],
#          [163, 169, 185]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.195690155029297, 'inference': 259.7849369049072, 'postprocess': 0.49304962158203125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [157, 166, 181],
#          [157, 166, 181],
#          [157, 166, 181]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [159, 165, 181],
#          [159, 165, 181],
#          [159, 165, 181]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.5548934936523438, 'inference': 192.41905212402344, 'postprocess': 0.5080699920654297},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [161, 165, 181],
#          [161, 165, 181],
#          [161, 165, 181]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.0607452392578125, 'inference': 185.50705909729004, 'postprocess': 0.5071163177490234},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [161, 165, 181],
#          [161, 165, 181],
#          [161, 165, 181]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.3040771484375, 'inference': 185.133695602417, 'postprocess': 0.5109310150146484},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [157, 166, 181],
#          [157, 166, 181],
#          [157, 166, 181]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.119230270385742, 'inference': 183.79902839660645, 'postprocess': 0.5109310150146484},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.5637149810791016, 'inference': 181.96988105773926, 'postprocess': 0.5156993865966797},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.9668807983398438, 'inference': 188.94267082214355, 'postprocess': 0.5209445953369141},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [158, 167, 182],
#          [158, 167, 182],
#          [158, 167, 182]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.374887466430664, 'inference': 192.26503372192383, 'postprocess': 0.5359649658203125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [166, 153, 144],
#          [166, 153, 144],
#          [166, 153, 144]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]],
#
#         [[ 57,  57,  64],
#          [ 57,  57,  64],
#          [ 57,  57,  64],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 8.802175521850586, 'inference': 247.1029758453369, 'postprocess': 0.5083084106445312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 59,  59,  66],
#          [ 61,  61,  68],
#          [ 63,  63,  70],
#          ...,
#          [160, 166, 182],
#          [160, 166, 182],
#          [160, 166, 182]],
#
#         [[ 76,  76,  83],
#          [ 75,  75,  82],
#          [ 72,  72,  79],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]],
#
#         [[ 84,  84,  91],
#          [ 82,  82,  89],
#          [ 77,  77,  84],
#          ...,
#          [162, 166, 182],
#          [162, 166, 182],
#          [162, 166, 182]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.7692317962646484, 'inference': 425.7988929748535, 'postprocess': 0.5199909210205078},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 59,  59,  66],
#          [ 61,  61,  68],
#          [ 63,  63,  70],
#          ...,
#          [165, 171, 187],
#          [168, 174, 190],
#          [169, 175, 191]],
#
#         [[ 76,  76,  83],
#          [ 75,  75,  82],
#          [ 72,  72,  79],
#          ...,
#          [165, 170, 183],
#          [165, 170, 183],
#          [165, 170, 183]],
#
#         [[ 84,  84,  91],
#          [ 82,  82,  89],
#          [ 77,  77,  84],
#          ...,
#          [163, 168, 181],
#          [162, 167, 180],
#          [162, 167, 180]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.094123840332031, 'inference': 183.2129955291748, 'postprocess': 0.5109310150146484},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 59,  59,  66],
#          [ 61,  61,  68],
#          [ 63,  63,  70],
#          ...,
#          [165, 171, 187],
#          [168, 174, 190],
#          [169, 175, 191]],
#
#         [[ 76,  76,  83],
#          [ 75,  75,  82],
#          [ 72,  72,  79],
#          ...,
#          [165, 170, 183],
#          [165, 170, 183],
#          [165, 170, 183]],
#
#         [[ 84,  84,  91],
#          [ 82,  82,  89],
#          [ 77,  77,  84],
#          ...,
#          [163, 168, 181],
#          [162, 167, 180],
#          [162, 167, 180]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.021240234375, 'inference': 186.04087829589844, 'postprocess': 0.514984130859375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 59,  59,  66],
#          [ 61,  61,  68],
#          [ 63,  63,  70],
#          ...,
#          [148, 154, 170],
#          [148, 154, 170],
#          [148, 154, 170]],
#
#         [[ 76,  76,  83],
#          [ 75,  75,  82],
#          [ 72,  72,  79],
#          ...,
#          [149, 154, 167],
#          [149, 154, 167],
#          [149, 154, 167]],
#
#         [[ 84,  84,  91],
#          [ 82,  82,  89],
#          [ 77,  77,  84],
#          ...,
#          [150, 155, 168],
#          [151, 156, 169],
#          [151, 156, 169]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.361867904663086, 'inference': 184.2648983001709, 'postprocess': 0.5190372467041016},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [148, 154, 170],
#          [148, 154, 170],
#          [148, 154, 170]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [149, 154, 167],
#          [149, 154, 167],
#          [149, 154, 167]],
#
#         [[ 57,  57,  64],
#          [ 58,  58,  65],
#          [ 58,  58,  65],
#          ...,
#          [150, 155, 168],
#          [151, 156, 169],
#          [151, 156, 169]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.3260116577148438, 'inference': 184.04769897460938, 'postprocess': 0.5159378051757812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [148, 154, 170],
#          [148, 154, 170],
#          [148, 154, 170]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [149, 154, 167],
#          [149, 154, 167],
#          [149, 154, 167]],
#
#         [[ 57,  57,  64],
#          [ 58,  58,  65],
#          [ 58,  58,  65],
#          ...,
#          [150, 155, 168],
#          [151, 156, 169],
#          [151, 156, 169]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.261089324951172, 'inference': 198.045015335083, 'postprocess': 0.5500316619873047},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [160, 166, 182],
#          [165, 171, 187],
#          [168, 174, 190]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [169, 174, 187],
#          [170, 175, 188],
#          [171, 176, 189]],
#
#         [[ 57,  57,  64],
#          [ 58,  58,  65],
#          [ 58,  58,  65],
#          ...,
#          [170, 175, 188],
#          [172, 177, 190],
#          [171, 176, 189]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.9010772705078125, 'inference': 237.03789710998535, 'postprocess': 0.5028247833251953},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 70,  70,  77],
#          ...,
#          [160, 166, 182],
#          [164, 170, 186],
#          [168, 174, 190]],
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [169, 174, 187],
#          [170, 175, 188],
#          [171, 176, 189]],
#
#         [[ 57,  57,  64],
#          [ 58,  58,  65],
#          [ 58,  58,  65],
#          ...,
#          [170, 175, 188],
#          [172, 177, 190],
#          [172, 177, 190]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.999948501586914, 'inference': 192.95310974121094, 'postprocess': 0.6380081176757812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 76,  76,  83],
#          [ 75,  75,  82],
#          [ 72,  72,  79],
#          ...,
#          [161, 167, 183],
#          [165, 171, 187],
#          [168, 174, 190]],
#
#         [[ 88,  88,  95],
#          [ 87,  87,  94],
#          [ 85,  85,  92],
#          ...,
#          [169, 174, 187],
#          [171, 176, 189],
#          [171, 176, 189]],
#
#         [[ 98,  98, 105],
#          [ 95,  95, 102],
#          [ 93,  93, 100],
#          ...,
#          [171, 176, 189],
#          [172, 177, 190],
#          [172, 177, 190]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.0329227447509766, 'inference': 187.87884712219238, 'postprocess': 0.5249977111816406},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 76,  76,  83],
#          [ 76,  76,  83],
#          [ 76,  76,  83],
#          ...,
#          [141, 147, 163],
#          [143, 149, 165],
#          [147, 153, 169]],
#
#         [[ 77,  77,  84],
#          [ 77,  77,  84],
#          [ 77,  77,  84],
#          ...,
#          [166, 171, 184],
#          [164, 169, 182],
#          [164, 169, 182]],
#
#         [[ 78,  78,  85],
#          [ 78,  78,  85],
#          [ 79,  79,  86],
#          ...,
#          [176, 181, 194],
#          [171, 176, 189],
#          [169, 174, 187]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.565073013305664, 'inference': 183.41612815856934, 'postprocess': 0.5171298980712891},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 97,  97, 104],
#          [ 95,  95, 102],
#          [ 92,  92,  99],
#          ...,
#          [141, 147, 163],
#          [143, 149, 165],
#          [147, 153, 169]],
#
#         [[ 71,  71,  78],
#          [ 73,  73,  80],
#          [ 78,  78,  85],
#          ...,
#          [166, 171, 184],
#          [164, 169, 182],
#          [164, 169, 182]],
#
#         [[ 30,  30,  37],
#          [ 34,  34,  41],
#          [ 40,  40,  47],
#          ...,
#          [176, 181, 194],
#          [171, 176, 189],
#          [169, 174, 187]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.822015762329102, 'inference': 190.629243850708, 'postprocess': 0.5102157592773438},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 92,  92,  99],
#          [ 93,  93, 100],
#          [ 91,  91,  98],
#          ...,
#          [141, 147, 163],
#          [143, 149, 165],
#          [147, 153, 169]],
#
#         [[ 59,  59,  66],
#          [ 62,  62,  69],
#          [ 66,  66,  73],
#          ...,
#          [166, 171, 184],
#          [164, 169, 182],
#          [164, 169, 182]],
#
#         [[ 29,  29,  36],
#          [ 30,  30,  37],
#          [ 36,  36,  43],
#          ...,
#          [176, 181, 194],
#          [171, 176, 189],
#          [169, 174, 187]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.5369396209716797, 'inference': 184.0970516204834, 'postprocess': 0.5197525024414062},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 70,  70,  77],
#          [ 70,  70,  77],
#          [ 71,  71,  78],
#          ...,
#          [141, 147, 163],
#          [143, 149, 165],
#          [147, 153, 169]],
#
#         [[ 61,  61,  68],
#          [ 61,  61,  68],
#          [ 62,  62,  69],
#          ...,
#          [166, 171, 184],
#          [164, 169, 182],
#          [164, 169, 182]],
#
#         [[ 42,  42,  49],
#          [ 42,  42,  49],
#          [ 43,  43,  50],
#          ...,
#          [176, 181, 194],
#          [171, 176, 189],
#          [169, 174, 187]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.733945846557617, 'inference': 182.9838752746582, 'postprocess': 0.5321502685546875},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 69,  69,  76],
#          [ 69,  69,  76],
#          [ 69,  69,  76],
#          ...,
#          [141, 147, 163],
#          [143, 149, 165],
#          [147, 153, 169]],
#
#         [[ 59,  59,  66],
#          [ 59,  59,  66],
#          [ 59,  59,  66],
#          ...,
#          [166, 171, 184],
#          [165, 170, 183],
#          [164, 169, 182]],
#
#         [[ 41,  41,  48],
#          [ 41,  41,  48],
#          [ 41,  41,  48],
#          ...,
#          [177, 182, 195],
#          [172, 177, 190],
#          [170, 175, 188]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.143238067626953, 'inference': 251.65891647338867, 'postprocess': 0.6880760192871094},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 63,  63,  70],
#          [ 63,  63,  70],
#          [ 63,  63,  70],
#          ...,
#          [141, 147, 163],
#          [143, 149, 165],
#          [147, 153, 169]],
#
#         [[ 64,  64,  71],
#          [ 64,  64,  71],
#          [ 64,  64,  71],
#          ...,
#          [163, 168, 181],
#          [161, 166, 179],
#          [159, 164, 177]],
#
#         [[ 40,  40,  47],
#          [ 40,  40,  47],
#          [ 40,  40,  47],
#          ...,
#          [176, 181, 194],
#          [171, 176, 189],
#          [167, 172, 185]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.407167434692383, 'inference': 201.75886154174805, 'postprocess': 0.5950927734375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         [[139, 131, 126],
#          [140, 132, 127],
#          [140, 132, 127],
#          ...,
#          [170, 157, 148],
#          [170, 157, 148],
#          [170, 157, 148]],
#
#         ...,
#
#         [[ 62,  62,  69],
#          [ 62,  62,  69],
#          [ 62,  62,  69],
#          ...,
#          [125, 131, 147],
# ...
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [127, 133, 149],
#          [127, 133, 149],
#          [127, 133, 149]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [130, 135, 148],
#          [130, 135, 148],
#          [130, 135, 148]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [130, 135, 148],
#          [130, 135, 148],
#          [130, 135, 148]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 7.439851760864258, 'inference': 369.6608543395996, 'postprocess': 0.5292892456054688},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [127, 133, 149],
#          [127, 133, 149],
#          [127, 133, 149]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [130, 135, 148],
#          [130, 135, 148],
#          [130, 135, 148]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [130, 135, 148],
#          [130, 135, 148],
#          [130, 135, 148]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 7.481098175048828, 'inference': 280.1821231842041, 'postprocess': 0.5080699920654297},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [127, 133, 149],
#          [127, 133, 149],
#          [127, 133, 149]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [130, 135, 148],
#          [130, 135, 148],
#          [130, 135, 148]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [130, 135, 148],
#          [130, 135, 148],
#          [130, 135, 148]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.433870315551758, 'inference': 410.6588363647461, 'postprocess': 0.6968975067138672},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [126, 132, 148],
#          [126, 132, 148],
#          [126, 132, 148]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [128, 133, 144],
#          [128, 133, 144],
#          [128, 133, 144]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [129, 134, 145],
#          [129, 134, 145],
#          [129, 134, 145]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 15.336990356445312, 'inference': 223.7091064453125, 'postprocess': 0.5109310150146484},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [126, 132, 148],
#          [126, 132, 148],
#          [126, 132, 148]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [128, 133, 144],
#          [128, 133, 144],
#          [128, 133, 144]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [129, 134, 145],
#          [129, 134, 145],
#          [129, 134, 145]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.236936569213867, 'inference': 240.72599411010742, 'postprocess': 0.5311965942382812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [126, 132, 148],
#          [126, 132, 148],
#          [126, 132, 148]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [128, 133, 144],
#          [128, 133, 144],
#          [128, 133, 144]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [129, 134, 145],
#          [129, 134, 145],
#          [129, 134, 145]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 5.602121353149414, 'inference': 230.84425926208496, 'postprocess': 0.6070137023925781},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [126, 132, 148],
#          [126, 132, 148],
#          [126, 132, 148]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [128, 133, 144],
#          [128, 133, 144],
#          [128, 133, 144]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [129, 134, 145],
#          [129, 134, 145],
#          [129, 134, 145]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.487037658691406, 'inference': 243.6363697052002, 'postprocess': 0.5602836608886719},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [126, 132, 148],
#          [126, 132, 148],
#          [126, 132, 148]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [128, 133, 144],
#          [128, 133, 144],
#          [128, 133, 144]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [129, 134, 145],
#          [129, 134, 145],
#          [129, 134, 145]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.965066909790039, 'inference': 345.9630012512207, 'postprocess': 0.5159378051757812},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[136, 143, 163],
#          [131, 138, 158],
#          [127, 134, 154],
#          ...,
#          [121, 128, 141],
#          [121, 128, 141],
#          [121, 128, 141]],
#
#         [[155, 160, 178],
#          [150, 155, 173],
#          [147, 152, 170],
#          ...,
#          [123, 128, 139],
#          [123, 128, 139],
#          [123, 128, 139]],
#
#         [[153, 158, 176],
#          [152, 157, 175],
#          [148, 153, 171],
#          ...,
#          [123, 128, 139],
#          [123, 128, 139],
#          [123, 128, 139]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 8.67605209350586, 'inference': 313.01093101501465, 'postprocess': 0.6530284881591797},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[111, 118, 138],
#          [110, 117, 137],
#          [110, 117, 137],
#          ...,
#          [121, 128, 141],
#          [121, 128, 141],
#          [121, 128, 141]],
#
#         [[131, 135, 156],
#          [129, 133, 154],
#          [129, 133, 154],
#          ...,
#          [123, 128, 139],
#          [123, 128, 139],
#          [123, 128, 139]],
#
#         [[131, 135, 156],
#          [131, 135, 156],
#          [129, 133, 154],
#          ...,
#          [123, 128, 139],
#          [123, 128, 139],
#          [123, 128, 139]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.506111145019531, 'inference': 295.81284523010254, 'postprocess': 0.6909370422363281},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pocket'}
#  obb: None
#  orig_img: array([[[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         [[151, 145, 140],
#          [151, 145, 140],
#          [151, 145, 140],
#          ...,
#          [175, 162, 158],
#          [175, 162, 158],
#          [175, 162, 158]],
#
#         ...,
#
#         [[111, 118, 138],
#          [110, 117, 137],
#          [110, 117, 137],
#          ...,
#          [121, 128, 141],
#          [121, 128, 141],
#          [121, 128, 141]],
#
#         [[131, 135, 156],
#          [129, 133, 154],
#          [129, 133, 154],
#          ...,
#          [123, 128, 139],
#          [123, 128, 139],
#          [123, 128, 139]],
#
#         [[131, 135, 156],
#          [131, 135, 156],
#          [129, 133, 154],
#          ...,
#          [123, 128, 139],
#          [123, 128, 139],
#          [123, 128, 139]]], dtype=uint8)
#  orig_shape: (1080, 1920)
#  path: '/Users/Paolo/code/PaoloPiacenti/wave_pocket_detection/video/preprocessed/test1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.673076629638672, 'inference': 235.76879501342773, 'postprocess': 0.5350112915039062},
#  ...]
